# %%
#Create term-test-1-result.csv

import csv

header = ['Registration Number', 'Name', 'TT-1 Marks']


data = [
    [f'2025REG{i:03}', f'Student {i}', 50 + i % 51]
    for i in range(1, 51)
]
with open('term-test-1-result.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(data)


# !ls -lh term-test-1-result.csv
# Out:
# -rw-r--r-- 1 root root 1.3K Feb 15 04:21 term-test-1-result.csv

# %%
from google.colab import files
files.download('term-test-1-result.csv')

# %%
import csv
from google.colab import files
import pandas as pd
import random

header1 = ['Registration Number', 'Name', 'TT-1 Marks']


data1 = [
    [f'2025REG{i:03}', f'Student {i}', random.randint(0, 20)]
    for i in range(1, 51)
]

# Write data to term-test-1 CSV file
with open('term-test-1-result.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header1)
    writer.writerows(data1)

# Verify the file is saved
# !ls -lh term-test-1-result.csv
#files.download('term-test-1-result.csv')


# Define the header for term-test-2
header2 = ['Registration Number', 'Name', 'TT-2 Marks']

# Generate sample data for 50 students for term-test-2
# (using the same registration numbers and names as term-test-1)
data2 = [
    [f'2025REG{i:03}', f'Student {i}', random.randint(0, 20)]
    for i in range(1, 51)
]

# Write data to term-test-2 CSV file
with open('term-test-2-result.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header2)
    writer.writerows(data2)

# Verify the file is saved
# !ls -lh term-test-2-result.csv
#files.download('term-test-2-result.csv')

# Load the CSV files into pandas DataFrames
df1 = pd.read_csv('term-test-1-result.csv')
df2 = pd.read_csv('term-test-2-result.csv')

# Merge the two dataframes based on 'Registration Number'
merged_df = pd.merge(df1, df2, on='Registration Number')

# Display the merged dataframe
merged_df
# Out:
# -rw-r--r-- 1 root root 1.3K Feb 15 04:23 term-test-1-result.csv
# -rw-r--r-- 1 root root 1.3K Feb 15 04:23 term-test-2-result.csv
#    Registration Number      Name_x  TT-1 Marks      Name_y  TT-2 Marks
# 0           2025REG001   Student 1           2   Student 1           0
# 1           2025REG002   Student 2          12   Student 2           9
# 2           2025REG003   Student 3           1   Student 3          10
# 3           2025REG004   Student 4           1   Student 4           0
# 4           2025REG005   Student 5           0   Student 5           2
# 5           2025REG006   Student 6           5   Student 6           3
# 6           2025REG007   Student 7          15   Student 7          14
# 7           2025REG008   Student 8           6   Student 8          11
# 8           2025REG009   Student 9          11   Student 9          19
# 9           2025REG010  Student 10          19  Student 10          16
# 10          2025REG011  Student 11           1  Student 11           9
# 11          2025REG012  Student 12          18  Student 12           2
# 12          2025REG013  Student 13           5  Student 13           0
# 13          2025REG014  Student 14          20  Student 14           2
# 14          2025REG015  Student 15          11  Student 15           9
# 15          2025REG016  Student 16          17  Student 16           0
# 16          2025REG017  Student 17          10  Student 17          18
# 17          2025REG018  Student 18          11  Student 18           7
# 18          2025REG019  Student 19          17  Student 19          16
# 19          2025REG020  Student 20           5  Student 20          18
# 20          2025REG021  Student 21           3  Student 21          15
# 21          2025REG022  Student 22          14  Student 22           5
# 22          2025REG023  Student 23          18  Student 23           1
# 23          2025REG024  Student 24           0  Student 24          10
# 24          2025REG025  Student 25          20  Student 25          18
# 25          2025REG026  Student 26           1  Student 26          16
# 26          2025REG027  Student 27          10  Student 27           0
# 27          2025REG028  Student 28           0  Student 28           3
# 28          2025REG029  Student 29          12  Student 29          19
# 29          2025REG030  Student 30          19  Student 30          16
# 30          2025REG031  Student 31          16  Student 31           8
# 31          2025REG032  Student 32          17  Student 32           7
# 32          2025REG033  Student 33          13  Student 33          11
# 33          2025REG034  Student 34           5  Student 34          12
# 34          2025REG035  Student 35          18  Student 35          11
# 35          2025REG036  Student 36          17  Student 36          10
# 36          2025REG037  Student 37           6  Student 37          13
# 37          2025REG038  Student 38          10  Student 38          10
# 38          2025REG039  Student 39           2  Student 39           0
# 39          2025REG040  Student 40           2  Student 40           8
# 40          2025REG041  Student 41          14  Student 41           0
# 41          2025REG042  Student 42          13  Student 42          15
# 42          2025REG043  Student 43           2  Student 43          10
# 43          2025REG044  Student 44          12  Student 44          10
# 44          2025REG045  Student 45           7  Student 45           8
# 45          2025REG046  Student 46           4  Student 46           7
# 46          2025REG047  Student 47           5  Student 47           1
# 47          2025REG048  Student 48          18  Student 48           6
# 48          2025REG049  Student 49          10  Student 49           7
# 49          2025REG050  Student 50          11  Student 50           2

# %%
files.download('term-test-2-result.csv')

# %%
files.download('term-test-1-result.csv')

# %%
# Calculate the best and average marks
merged_df['Best TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)
merged_df['Average TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)

# Display the updated DataFrame
print(merged_df.head())
# Out:
#   Registration Number     Name_x  TT-1 Marks     Name_y  TT-2 Marks  \
# 0          2025REG001  Student 1           2  Student 1           0
# 1          2025REG002  Student 2          12  Student 2           9
# 2          2025REG003  Student 3           1  Student 3          10
# 3          2025REG004  Student 4           1  Student 4           0
# 4          2025REG005  Student 5           0  Student 5           2
#
#    Best TT Marks  Average TT Marks
# 0              2               1.0
# 1             12              10.5
# 2             10               5.5
# 3              1               0.5
# 4              2               1.0

# %%
merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'])

print(merged_df.head())
# Out:
#   Registration Number     Name_x  TT-1 Marks     Name_y  TT-2 Marks  \
# 0          2025REG001  Student 1           2  Student 1           0
# 1          2025REG002  Student 2          12  Student 2           9
# 2          2025REG003  Student 3           1  Student 3          10
# 3          2025REG004  Student 4           1  Student 4           0
# 4          2025REG005  Student 5           0  Student 5           2
#
#    Best TT Marks  Average TT Marks
# 0              2               1.0
# 1             12              10.5
# 2             10               5.5
# 3              1               0.5
# 4              2               1.0

# %%
attendance_term_final_data = []
for student in data:
    reg_num = student[0]
    attendance_marks = random.randint(0, 10)  # Random attendance marks between 0 and 10
    term_final_marks = random.randint(0, 100)  # Random term final marks between 0 and 100
    attendance_term_final_data.append([reg_num, attendance_marks, term_final_marks])

# Write to CSV
attendance_header = ['Registration Number', 'Attendance Marks', 'Term Final Marks']
with open('attendance_term_final.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(attendance_header)
    writer.writerows(attendance_term_final_data)

# Load the new CSV into a DataFrame
df_attendance_final = pd.read_csv('attendance_term_final.csv')

# Merge with the existing DataFrame
final_df = pd.merge(merged_df, df_attendance_final, on='Registration Number')

# Calculate 'Final Marks'
final_df['Final Marks'] = final_df['Term Final Marks'] * 0.7 + final_df['Average TT Marks'] + final_df['Attendance Marks']

# Display the final DataFrame
print(final_df.head())
# Out:
#   Registration Number     Name_x  TT-1 Marks     Name_y  TT-2 Marks  \
# 0          2025REG001  Student 1           2  Student 1           0
# 1          2025REG002  Student 2          12  Student 2           9
# 2          2025REG003  Student 3           1  Student 3          10
# 3          2025REG004  Student 4           1  Student 4           0
# 4          2025REG005  Student 5           0  Student 5           2
#
#    Best TT Marks  Average TT Marks  Attendance Marks  Term Final Marks  \
# 0              2               1.0                 1                27
# 1             12              10.5                 9                29
# 2             10               5.5                 3                36
# 3              1               0.5                 1                19
# 4              2               1.0                 0                35
#
#    Final Marks
# 0         20.9
# 1         39.8
# 2         33.7
# 3         14.8
# 4         25.5

# %%
# Write the final DataFrame to CSV
final_df.to_csv('final_result.csv', index=False)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Extract 'Final Marks' for clustering
X = final_df[['Final Marks']]

# Determine the optimal number of clusters (K) using the elbow method
inertia = []
K_range = range(1, 6)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)



# Choose K (e.g., K=3 based on the elbow plot) and fit K-Means
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
final_df['Cluster'] = kmeans.fit_predict(X)

# Visualize the clusters
plt.figure(figsize=(8, 5))
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Extract 'Final Marks' for clustering
X = final_df[['Final Marks']]

# Determine the optimal number of clusters (K) using the elbow method
inertia = []
K_range = range(1, 6)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)



# Choose K (e.g., K=3 based on the elbow plot) and fit K-Means
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
final_df['Cluster'] = kmeans.fit_predict(X)

# Visualize the clusters
plt.figure(figsize=(8, 5))
for cluster in range(optimal_k):
    cluster_data = final_df[final_df['Cluster'] == cluster]
    plt.scatter(cluster_data['Registration Number'],
                cluster_data['Final Marks'], label=f'Cluster {cluster}')
plt.xlabel('Registration Number')
plt.ylabel('Final Marks')
plt.title('K-Means Clustering of Final Marks')
plt.legend()
plt.show()
